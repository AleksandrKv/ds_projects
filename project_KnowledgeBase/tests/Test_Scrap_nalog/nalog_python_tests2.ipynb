# %%
import json
import os
import requests
from dotenv import load_dotenv

# https://leftjoin.ru/all/nalog-ru-client/   - страница, а в ней ссылка на исходники на GetHab6

class NalogRuPython:
    HOST = 'irkkt-mobile.nalog.ru:8888'
    DEVICE_OS = 'iOS'
    CLIENT_VERSION = '2.9.0'
    DEVICE_ID = '7C82010F-16CC-446B-8F66-FC4080C66521'
    ACCEPT = '*/*'
    USER_AGENT = 'billchecker/2.9.0 (iPhone; iOS 13.6; Scale/2.00)'
    ACCEPT_LANGUAGE = 'ru-RU;q=1, en-US;q=0.9'
    CLIENT_SECRET = 'IyvrAbKt9h/8p6a7QPh8gpkXYQ4='
    OS = 'Android'

    def __init__(self):
        self.__session_id = None
        self.set_session_id()

    def set_session_id(self) -> None:
        """
        Authorization using phone and SMS code
        """
        self.__phone = str('+79182545549')
        # self.__phone = str(input('Input phone in +70000000000 format: '))

        url = f'https://{self.HOST}/v2/auth/phone/request'
        payload = {
            'phone': self.__phone,
            'client_secret': self.CLIENT_SECRET,
            'os': self.OS
        }
        headers = {
            'Host': self.HOST,
            'Accept': self.ACCEPT,
            'Device-OS': self.DEVICE_OS,
            'Device-Id': self.DEVICE_ID,
            'clientVersion': self.CLIENT_VERSION,
            'Accept-Language': self.ACCEPT_LANGUAGE,
            'User-Agent': self.USER_AGENT,
        }

        resp = requests.post(url, json=payload, headers=headers)

        self.__code = input('Input code from SMS: ')

        url = f'https://{self.HOST}/v2/auth/phone/verify'
        payload = {
        'phone': self.__phone,
        'client_secret': self.CLIENT_SECRET,
        'code': self.__code,
        "os": self.OS
        }

        resp = requests.post(url, json=payload, headers=headers)

        self.__session_id = resp.json()['sessionId']
        self.__refresh_token = resp.json()['refresh_token']

    def refresh_token_function(self) -> None:
        url = f'https://{self.HOST}/v2/mobile/users/refresh'
        payload = {
            'refresh_token': self.__refresh_token,
            'client_secret': self.CLIENT_SECRET
        }

        headers = {
            'Host': self.HOST,
            'Accept': self.ACCEPT,
            'Device-OS': self.DEVICE_OS,
            'Device-Id': self.DEVICE_ID,
            'clientVersion': self.CLIENT_VERSION,
            'Accept-Language': self.ACCEPT_LANGUAGE,
            'User-Agent': self.USER_AGENT,
        }

        resp = requests.post(url, json=payload, headers=headers)

        self.__session_id = resp.json()['sessionId']
        self.__refresh_token = resp.json()['refresh_token']

    def _get_ticket_id(self, qr: str) -> str:
        """
        Get ticker id by info from qr code
        :param qr: text from qr code. Example "t=20200727T174700&s=746.00&fn=9285000100206366&i=34929&fp=3951774668&n=1"
        :return: Ticket id. Example "5f3bc6b953d5cb4f4e43a06c"
        """
        url = f'https://{self.HOST}/v2/ticket'
        payload = {'qr': qr}
        headers = {
            'Host': self.HOST,
            'Accept': self.ACCEPT,
            'Device-OS': self.DEVICE_OS,
            'Device-Id': self.DEVICE_ID,
            'clientVersion': self.CLIENT_VERSION,
            'Accept-Language': self.ACCEPT_LANGUAGE,
            'sessionId': self.__session_id,
            'User-Agent': self.USER_AGENT,
        }

        resp = requests.post(url, json=payload, headers=headers)

        return resp.json()["id"]

    def get_ticket(self, qr: str) -> dict:
        """
        Get JSON ticket
        :param qr: text from qr code. Example "t=20200727T174700&s=746.00&fn=9285000100206366&i=34929&fp=3951774668&n=1"
        :return: JSON ticket
        """
        ticket_id = self._get_ticket_id(qr)
        url = f'https://{self.HOST}/v2/tickets/{ticket_id}'
        headers = {
            'Host': self.HOST,
            'sessionId': self.__session_id,
            'Device-OS': self.DEVICE_OS,
            'clientVersion': self.CLIENT_VERSION,
            'Device-Id': self.DEVICE_ID,
            'Accept': self.ACCEPT,
            'User-Agent': self.USER_AGENT,
            'Accept-Language': self.ACCEPT_LANGUAGE,
            'Content-Type': 'application/json'
        }

        resp = requests.get(url, headers=headers)

        return resp.json()


    def get_tickets(self) -> str:
        """
        tickets
        """
        url = f'https://{self.HOST}/v2/tickets/'
        # payload = {'qr': qr}
        payload = {}
        headers = {
            'Host': self.HOST,
            'Accept': self.ACCEPT,
            'Device-OS': self.DEVICE_OS,
            'Device-Id': self.DEVICE_ID,
            'clientVersion': self.CLIENT_VERSION,
            'Accept-Language': self.ACCEPT_LANGUAGE,
            'sessionId': self.__session_id,
            'User-Agent': self.USER_AGENT,
        }

        resp = requests.post(url, headers=headers)

        return resp

    def print_session_id(self):
        print("session_id:", client.__session_id)
        print("refresh_token:", client.__refresh_token)

    def get_session_id(self):
        return self.__session_id


# 625e7d48eea5e2770b220c75:7c10915d-3fc0-40c9-8d54-8dece81eab61


client = NalogRuPython()
client.print_session_id()

# qr_code = "t=20200709T2008&s=7273.00&fn=9282440300688488&i=14186&fp=1460060363&n=1"
# ticket = client.get_ticket(qr_code)
# print(json.dumps(ticket, indent=4, ensure_ascii=False))
# Out:
# session_id: 625e7d48eea5e2770b220c75:03cb1d76-220d-4d7a-aced-230d6f4e716d
# refresh_token: 17208ca4-4260-4894-84ae-fa9c95288165

# %%
# global phone
# global CLIENT_SECRET

phone = str('+79182545549')
CLIENT_SECRET = 'IyvrAbKt9h/8p6a7QPh8gpkXYQ4='

# %%
# global session_id
# global refresh_token

session_id = '625e7d48eea5e2770b220c75:03cb1d76-220d-4d7a-aced-230d6f4e716d'
refresh_token = '17208ca4-4260-4894-84ae-fa9c95288165'

# %%
# Объявляем функции (не вызывая их)

import json
import os
import requests
from dotenv import load_dotenv

def get_session_id():
    """
    Authorization using phone and SMS code
    """
    global phone 
    global CLIENT_SECRET

    url = 'https://irkkt-mobile.nalog.ru:8888/v2/mobile/users/refresh'
    payload = {
        'phone': phone,
        'client_secret': CLIENT_SECRET,
        'os': 'Android'
    }
    headers = {
        'Host': 'irkkt-mobile.nalog.ru:8888',
        'Accept': '*/*',
        'Device-OS': 'iOS',
        'Device-Id': '7C82010F-16CC-446B-8F66-FC4080C66521',
        'clientVersion': '2.9.0',
        'Accept-Language': 'ru-RU;q=1, en-US;q=0.9',
        'User-Agent': 'billchecker/2.9.0 (iPhone; iOS 13.6; Scale/2.00)',
    }    
    resp = requests.post(url, json=payload, headers=headers)

    # SMScode
    SMScode = input('Input code from SMS: ')

    url = 'https://irkkt-mobile.nalog.ru:8888/v2/mobile/users/refresh'
    payload = {
        'phone': phone,
        'client_secret': CLIENT_SECRET,
        'code': SMScode,
        'os': 'Android'
    }

    resp = requests.post(url, json=payload, headers=headers)
    result = {
        'session_id': resp.json()['sessionId'],
        'refresh_token': resp.json()['refresh_token']
    }

    global refresh_token
    global session_id

    session_id = resp.json()['sessionId']
    refresh_token = resp.json()['refresh_token']

    return 'get_session_id: Ok'

def set_refresh_token():
    
    global refresh_token
    global session_id

    url = 'https://irkkt-mobile.nalog.ru:8888/v2/mobile/users/refresh'
    payload = {
        'refresh_token': refresh_token,
        'client_secret': 'IyvrAbKt9h/8p6a7QPh8gpkXYQ4='
    }

    headers = {
        'Host': 'irkkt-mobile.nalog.ru:8888',
        'Accept': '*/*',
        'Device-OS': 'iOS',
        'Device-Id': '7C82010F-16CC-446B-8F66-FC4080C66521',
        'clientVersion': '2.9.0',
        'Accept-Language': 'ru-RU;q=1, en-US;q=0.9',
        'User-Agent': 'billchecker/2.9.0 (iPhone; iOS 13.6; Scale/2.00)',
    }

    resp = requests.post(url, json=payload, headers=headers)

    session_id = resp.json()['sessionId']
    refresh_token = resp.json()['refresh_token']

    return 'refresh_token: Ok'

def get_ticket(qr: str) -> dict:
    """
    Get JSON ticket
    :param qr: text from qr code. Example "t=20200727T174700&s=746.00&fn=9285000100206366&i=34929&fp=3951774668&n=1"
    :return: JSON ticket
    """
    global session_id

    def get_ticket_id(qr: str) -> str:
        """
        Get ticker id by info from qr code
        :param qr: text from qr code. Example "t=20200727T174700&s=746.00&fn=9285000100206366&i=34929&fp=3951774668&n=1"
        :return: Ticket id. Example "5f3bc6b953d5cb4f4e43a06c"
        """
        url = 'https://irkkt-mobile.nalog.ru:8888/v2/ticket'
        payload = {'qr': qr}
        headers = {
            'Host': 'irkkt-mobile.nalog.ru:8888',
            'Accept': '*/*',
            'Device-OS': 'iOS',
            'Device-Id': '7C82010F-16CC-446B-8F66-FC4080C66521',
            'clientVersion': '2.9.0',
            'Accept-Language': 'ru-RU;q=1, en-US;q=0.9',
            'sessionId': session_id,
            'User-Agent': 'billchecker/2.9.0 (iPhone; iOS 13.6; Scale/2.00)',
        }

        resp = requests.post(url, json=payload, headers=headers)

        return resp.json()["id"]    

    # get_ticket_id
    ticket_id = get_ticket_id(qr)

    # get_ticket
    url = f'https://irkkt-mobile.nalog.ru:8888/v2/tickets/{ticket_id}'
    headers = {
        'Host': 'irkkt-mobile.nalog.ru:8888',
        'sessionId': session_id,
        'Accept': '*/*',
        'Device-OS': 'iOS',
        'Device-Id': '7C82010F-16CC-446B-8F66-FC4080C66521',
        'clientVersion': '2.9.0',
        'Accept-Language': 'ru-RU;q=1, en-US;q=0.9',
        'User-Agent': 'billchecker/2.9.0 (iPhone; iOS 13.6; Scale/2.00)',
        'Content-Type': 'application/json'
    }

    resp = requests.get(url, headers=headers)

    return resp.json()

# %%
refresh_token = '51842bb3-79c0-4eb5-a242-fe236692e1ca'

# %%
# Получить session_id and refresh_token
get_session_id()
print('session_id:', session_id)
print('refresh_token:', refresh_token)

# %%
# Обновить session_id and refresh_token
set_refresh_token()
print('session_id:', session_id)
print('refresh_token:', refresh_token)
# Out:
# session_id: 625e7d48eea5e2770b220c75:341dda6a-2f16-4162-aa27-4ab3b43b184f
# refresh_token: ee4f2b75-6231-44ab-88be-41fa4034d175

# %%
qr_code = "t=20200709T2008&s=7273.00&fn=9282440300688488&i=14186&fp=1460060363&n=1"
set_refresh_token()
ticket = get_ticket(qr_code)
ticket
# print(json.dumps(ticket, indent=4, ensure_ascii=False))

# %%
def get_tickets():

    global session_id

    url = 'https://irkkt-mobile.nalog.ru:8888/v2/tickets'
    payload = {
        'client_secret': 'IyvrAbKt9h/8p6a7QPh8gpkXYQ4=',
        'os': 'Android'
    }

    headers = {
        'Host': 'irkkt-mobile.nalog.ru:8888',
        'Accept': '*/*',
        'Device-OS': 'iOS',
        'Device-Id': '7C82010F-16CC-446B-8F66-FC4080C66521',
        'clientVersion': '2.9.0',
        'Accept-Language': 'ru-RU;q=1, en-US;q=0.9',
        'sessionId': session_id,
        'User-Agent': 'billchecker/2.9.0 (iPhone; iOS 13.6; Scale/2.00)',
        'Content-Type': 'application/json'
    }

    # resp = requests.post(url, json=payload, headers=headers)
    resp = requests.post(url, headers=headers)

    return resp

set_refresh_token()
res = get_tickets()
print(res)
res.json()
# Out:
# <Response [405]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# d:\IDE_prj\project_KnowledgeBase\Test_Scrap_nalog\nalog_python_tests2.ipynb Cell 9' in <module>
#      <a href='vscode-notebook-cell:/d%3A/IDE_prj/project_KnowledgeBase/Test_Scrap_nalog/nalog_python_tests2.ipynb#ch0000003?line=28'>29</a> res = get_tickets()
#      <a href='vscode-notebook-cell:/d%3A/IDE_prj/project_KnowledgeBase/Test_Scrap_nalog/nalog_python_tests2.ipynb#ch0000003?line=29'>30</a> print(res)
# ---> <a href='vscode-notebook-cell:/d%3A/IDE_prj/project_KnowledgeBase/Test_Scrap_nalog/nalog_python_tests2.ipynb#ch0000003?line=30'>31</a> res.json()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py:898, in Response.json(self, **kwargs)
# ...

# %%
res
# Out:
# <Response [405]>
